# %%
import os
from info_retrieval import WinnersFillingForm

#### PATH TO THE DOCUMENTS ####
documents_directory = "data"
path_to_files = [os.path.join(documents_directory, file) for file in os.listdir(documents_directory)]
assert len(path_to_files) == 10
path_to_files.sort()  # SORT AS IT IS ESSENTIAL (ASKIP)

class_model = WinnersFillingForm(None, None, None)  # TO IMPLEMENT

# %%
results = {}
for i, path in enumerate(path_to_files):
    with open(path, "r") as input_file:
        text = input_file.read()  # Here we have all the document's text
    all_answers = class_model.answer(text)
    for answer in all_answers:
        question_number = answer['question_id'] + i*22  # TO IMPLEMENT WITH THE CLASS MODEL
        results[question_number] = answer['answer_id']
assert len(results) == len(path_to_files) * 22
assert set(list(results.keys())) == {i for i in range(1, 221)}
# Out:
# here
# 1
# 2
# 3
# 4
# 5
# 8
# 9
# 11
# 13
# 14
# 15
# 16
# 17
# 18
# 21
# 22
# here
# 1
# 2
# 3
# 4
# 5
# 8
# 9
# 11
# 13
# 14
# 15
# 16
# 17
# 18
# 21
# 22
# here
# 1
# 2
# 3
# 4
# 5
# 8
# 9
# 11
# 13
# 14
# 15
# 16
# 17
# 18
# 21
# 22
# here
# 1
# 2
# 3
# 4
# 5
# 8
# 9
# 11
# 13
# 14
# 15
# 16
# 17
# 18
# 21
# 22
# here
# 1
# 2
# 3
# 4
# 5
# 8
# 9
# 11
# 13
# 14
# 15
# 16
# 17
# 18
# 21
# 22
# here
# 1
# 2
# 3
# 4
# 5
# 8
# 9
# 11
# 13
# 14
# 15
# 16
# 17
# 18
# 21
# 22
# here
# 1
# 2
# 3
# 4
# 5
# 8
# 9
# 11
# 13
# 14
# 15
# 16
# 17
# 18
# 21
# 22
# here
# 1
# 2
# 3
# 4
# 5
# 8
# 9
# 11
# 13
# 14
# 15
# 16
# 17
# 18
# 21
# 22
# here
# 1
# 2
# 3
# 4
# 5
# 8
# 9
# 11
# 13
# 14
# 15
# 16
# 17
# 18
# 21
# 22
# here
# 1
# 2
# 3
# 4
# 5
# 8
# 9
# 11
# 13
# 14
# 15
# 16
# 17
# 18
# 21
# 22

# %%
from questions import CountryQuestions

# %%
CountryQuestions.id_to_questions[5]
# Out:
# 'In which countries outside of the EU the data can be transferred to ?'

# %%
CountryQuestions.questions_to_id['In which countries outside of the EU the data can be transferred to ?']
# Out:
# [5, 6, 7]

# %%
len(results)
# Out:
# 160

# %%
results
# Out:
# {1: 1,
#  2: 1,
#  3: 1,
#  4: 1,
#  5: 840,
#  8: 1,
#  9: 840,
#  11: 840,
#  13: 1,
#  14: 1,
#  15: 1,
#  16: 1,
#  17: 1,
#  18: 840,
#  21: 1,
#  22: 1,
#  23: 1,
#  24: 1,
#  25: 1,
#  26: 1,
#  27: 840,
#  30: 1,
#  31: 840,
#  33: 840,
#  35: 1,
#  36: 1,
#  37: 1,
#  38: 1,
#  39: 1,
#  40: 840,
#  43: 1,
#  44: 1,
#  45: 1,
#  46: 1,
#  47: 1,
#  48: 1,
#  49: 840,
#  52: 1,
#  53: 840,
#  55: 840,
#  57: 1,
#  58: 1,
#  59: 1,
#  60: 1,
#  61: 1,
#  62: 840,
#  65: 1,
#  66: 1,
#  67: 1,
#  68: 1,
#  69: 1,
#  70: 1,
#  71: 840,
#  74: 1,
#  75: 840,
#  77: 840,
#  79: 1,
#  80: 1,
#  81: 1,
#  82: 1,
#  83: 1,
#  84: 840,
#  87: 1,
#  88: 1,
#  89: 1,
#  90: 1,
#  91: 1,
#  92: 1,
#  93: 840,
#  96: 1,
#  97: 840,
#  99: 840,
#  101: 1,
#  102: 1,
#  103: 1,
#  104: 1,
#  105: 1,
#  106: 840,
#  109: 1,
#  110: 1,
#  111: 1,
#  112: 1,
#  113: 1,
#  114: 1,
#  115: 840,
#  118: 1,
#  119: 840,
#  121: 840,
#  123: 1,
#  124: 1,
#  125: 1,
#  126: 1,
#  127: 1,
#  128: 840,
#  131: 1,
#  132: 1,
#  133: 1,
#  134: 1,
#  135: 1,
#  136: 1,
#  137: 840,
#  140: 1,
#  141: 840,
#  143: 840,
#  145: 1,
#  146: 1,
#  147: 1,
#  148: 1,
#  149: 1,
#  150: 840,
#  153: 1,
#  154: 1,
#  155: 1,
#  156: 1,
#  157: 1,
#  158: 1,
#  159: 840,
#  162: 1,
#  163: 840,
#  165: 840,
#  167: 1,
#  168: 1,
#  169: 1,
#  170: 1,
#  171: 1,
#  172: 840,
#  175: 1,
#  176: 1,
#  177: 1,
#  178: 1,
#  179: 1,
#  180: 1,
#  181: 840,
#  184: 1,
#  185: 840,
#  187: 840,
#  189: 1,
#  190: 1,
#  191: 1,
#  192: 1,
#  193: 1,
#  194: 840,
#  197: 1,
#  198: 1,
#  199: 1,
#  200: 1,
#  201: 1,
#  202: 1,
#  203: 840,
#  206: 1,
#  207: 840,
#  209: 840,
#  211: 1,
#  212: 1,
#  213: 1,
#  214: 1,
#  215: 1,
#  216: 840,
#  219: 1,
#  220: 1}

# %%
[{'answer_id': answer_id, 'question_id': i} for answer_id, i in zip([1,2], [1,2])]
# Out:
# [{'answer_id': 1, 'question_id': 1}, {'answer_id': 2, 'question_id': 2}]

# %%
results
# Out:
# {1: 1,
#  2: 1,
#  3: 1,
#  4: 1,
#  5: 840,
#  6: 0,
#  7: 0,
#  8: 1,
#  9: 840,
#  10: 0,
#  11: 840,
#  12: 0,
#  13: 1,
#  14: 1,
#  15: 1,
#  16: 1,
#  17: 1,
#  18: 840,
#  19: 0,
#  20: 0,
#  21: 1,
#  22: 1,
#  23: 1,
#  24: 1,
#  25: 1,
#  26: 1,
#  27: 840,
#  28: 0,
#  29: 0,
#  30: 1,
#  31: 840,
#  32: 0,
#  33: 840,
#  34: 0,
#  35: 1,
#  36: 1,
#  37: 1,
#  38: 1,
#  39: 1,
#  40: 840,
#  41: 0,
#  42: 0,
#  43: 1,
#  44: 1,
#  45: 1,
#  46: 1,
#  47: 1,
#  48: 1,
#  49: 840,
#  50: 0,
#  51: 0,
#  52: 1,
#  53: 840,
#  54: 0,
#  55: 840,
#  56: 0,
#  57: 1,
#  58: 1,
#  59: 1,
#  60: 1,
#  61: 1,
#  62: 840,
#  63: 0,
#  64: 0,
#  65: 1,
#  66: 1,
#  67: 1,
#  68: 1,
#  69: 1,
#  70: 1,
#  71: 840,
#  72: 0,
#  73: 0,
#  74: 1,
#  75: 840,
#  76: 0,
#  77: 840,
#  78: 0,
#  79: 1,
#  80: 1,
#  81: 1,
#  82: 1,
#  83: 1,
#  84: 840,
#  85: 0,
#  86: 0,
#  87: 1,
#  88: 1,
#  89: 1,
#  90: 1,
#  91: 1,
#  92: 1,
#  93: 840,
#  94: 0,
#  95: 0,
#  96: 1,
#  97: 840,
#  98: 0,
#  99: 840,
#  100: 0,
#  101: 1,
#  102: 1,
#  103: 1,
#  104: 1,
#  105: 1,
#  106: 840,
#  107: 0,
#  108: 0,
#  109: 1,
#  110: 1,
#  111: 1,
#  112: 1,
#  113: 1,
#  114: 1,
#  115: 840,
#  116: 0,
#  117: 0,
#  118: 1,
#  119: 840,
#  120: 0,
#  121: 840,
#  122: 0,
#  123: 1,
#  124: 1,
#  125: 1,
#  126: 1,
#  127: 1,
#  128: 840,
#  129: 0,
#  130: 0,
#  131: 1,
#  132: 1,
#  133: 1,
#  134: 1,
#  135: 1,
#  136: 1,
#  137: 840,
#  138: 0,
#  139: 0,
#  140: 1,
#  141: 840,
#  142: 0,
#  143: 840,
#  144: 0,
#  145: 1,
#  146: 1,
#  147: 1,
#  148: 1,
#  149: 1,
#  150: 840,
#  151: 0,
#  152: 0,
#  153: 1,
#  154: 1,
#  155: 1,
#  156: 1,
#  157: 1,
#  158: 1,
#  159: 840,
#  160: 0,
#  161: 0,
#  162: 1,
#  163: 840,
#  164: 0,
#  165: 840,
#  166: 0,
#  167: 1,
#  168: 1,
#  169: 1,
#  170: 1,
#  171: 1,
#  172: 840,
#  173: 0,
#  174: 0,
#  175: 1,
#  176: 1,
#  177: 1,
#  178: 1,
#  179: 1,
#  180: 1,
#  181: 840,
#  182: 0,
#  183: 0,
#  184: 1,
#  185: 840,
#  186: 0,
#  187: 840,
#  188: 0,
#  189: 1,
#  190: 1,
#  191: 1,
#  192: 1,
#  193: 1,
#  194: 840,
#  195: 0,
#  196: 0,
#  197: 1,
#  198: 1,
#  199: 1,
#  200: 1,
#  201: 1,
#  202: 1,
#  203: 840,
#  204: 0,
#  205: 0,
#  206: 1,
#  207: 840,
#  208: 0,
#  209: 840,
#  210: 0,
#  211: 1,
#  212: 1,
#  213: 1,
#  214: 1,
#  215: 1,
#  216: 840,
#  217: 0,
#  218: 0,
#  219: 1,
#  220: 1}

# %%
list(sorted([1])) + [0]*(-3)
# Out:
# [1]
